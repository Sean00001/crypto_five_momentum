# %%
import csv
import pandas as pd
import talib
import numpy as np

# %%
# data = pd.read_csv("cryptoday.csv")

# %%
# data = data.astype('float64')

# %%
data = pd.read_csv("全幣種-週價格(程式).csv")

# %%
#data

# %%
data = data.dropna()

# %%
#data.head(10)

# %%
data['BTC']
# Out:
# 0     10815.7
# 1     11314.5
# 2     10218.1
# 3     10131.0
# 4      9594.4
#        ...
# 85    58093.4
# 86    55862.9
# 87    57059.9
# 88    59748.4
# 89    64509.0
# Name: BTC, Length: 90, dtype: float64

# %%
type(data['BTC'])
# Out:
# pandas.core.series.Series

# %%
type(data['BTC'])
# Out:
# pandas.core.series.Series

# %%
data['BTC']
# Out:
# 0     10815.7
# 1     11314.5
# 2     10218.1
# 3     10131.0
# 4      9594.4
#        ...
# 85    58093.4
# 86    55862.9
# 87    57059.9
# 88    59748.4
# 89    64509.0
# Name: BTC, Length: 90, dtype: float64

# %%
SMA = talib.SMA(data['BTC'],20)

# %%
SMA
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#         ...
# 85    34346.890
# 86    36398.615
# 87    38448.060
# 88    40501.120
# 89    42840.035
# Length: 90, dtype: float64

# %%
BBI = np.where((data["BTC"]- SMA> 0),1, 0)
seven = data.shift(6)

# %%
#reward = data["BTC"].rolling(window = 9)

# %%
today = data.drop(['Date'], axis=1)

# %%
sevenago = seven.drop(['Date'], axis=1)

# %%
today
# Out:
#         BTC       ADA     ARDR     ATOM    ALGO      BAT     BCH     BNB  \
# 0   10815.7  0.057739  0.06634   3.6882  0.7438  0.23479  335.39   27.74
# 1   11314.5  0.051980  0.05567   3.3458  0.8104  0.20275  316.13   29.60
# 2   10218.1  0.047360  0.05311   2.9089  0.6841  0.17675  306.59   27.45
# 3   10131.0  0.050097  0.06279   2.6917  0.5782  0.20312  305.52   26.44
# 4    9594.4  0.044777  0.05375   2.0140  0.4083  0.17708  279.25   21.22
# ..      ...       ...      ...      ...     ...      ...     ...     ...
# 85  58093.4  1.200409  0.28091  20.8997  1.2120  1.08189  536.21  264.10
# 86  55862.9  1.176785  0.28380  18.7088  1.1594  1.08166  500.34  269.32
# 87  57059.9  1.163307  0.35063  20.0322  1.2608  1.11515  530.76  321.53
# 88  59748.4  1.217928  0.65042  21.0379  1.3880  1.46425  672.51  472.25
# 89  64509.0  1.527384  0.46099  24.1419  1.4777  1.51468  812.50  579.42
#
#         BNT      BTS  ...    REP       SNT    THETA       TRX       VET  \
# ...

# %%
# type(today)
today = today.astype('float64')

# %%
type(sevenago)
# Out:
# pandas.core.frame.DataFrame

# %%
today
# Out:
#         BTC       ADA     ARDR     ATOM    ALGO      BAT     BCH     BNB  \
# 0   10815.7  0.057739  0.06634   3.6882  0.7438  0.23479  335.39   27.74
# 1   11314.5  0.051980  0.05567   3.3458  0.8104  0.20275  316.13   29.60
# 2   10218.1  0.047360  0.05311   2.9089  0.6841  0.17675  306.59   27.45
# 3   10131.0  0.050097  0.06279   2.6917  0.5782  0.20312  305.52   26.44
# 4    9594.4  0.044777  0.05375   2.0140  0.4083  0.17708  279.25   21.22
# ..      ...       ...      ...      ...     ...      ...     ...     ...
# 85  58093.4  1.200409  0.28091  20.8997  1.2120  1.08189  536.21  264.10
# 86  55862.9  1.176785  0.28380  18.7088  1.1594  1.08166  500.34  269.32
# 87  57059.9  1.163307  0.35063  20.0322  1.2608  1.11515  530.76  321.53
# 88  59748.4  1.217928  0.65042  21.0379  1.3880  1.46425  672.51  472.25
# 89  64509.0  1.527384  0.46099  24.1419  1.4777  1.51468  812.50  579.42
#
#         BNT      BTS  ...    REP       SNT    THETA       TRX       VET  \
# ...

# %%
# today.astype(float)
today = today.astype(float, errors = 'raise')

# %%
# sevenago.astype(int)

# %%
sevenago
# Out:
#         BTC       ADA     ARDR     ATOM    ALGO      BAT     BCH     BNB  \
# 0       NaN       NaN      NaN      NaN     NaN      NaN     NaN     NaN
# 1       NaN       NaN      NaN      NaN     NaN      NaN     NaN     NaN
# 2       NaN       NaN      NaN      NaN     NaN      NaN     NaN     NaN
# 3       NaN       NaN      NaN      NaN     NaN      NaN     NaN     NaN
# 4       NaN       NaN      NaN      NaN     NaN      NaN     NaN     NaN
# ..      ...       ...      ...      ...     ...      ...     ...     ...
# 85  39256.6  0.633867  0.10692  12.0672  0.8077  0.35271  458.06   72.58
# 86  47168.7  0.911147  0.12347  20.2464  1.6600  0.61702  667.88  133.07
# 87  55923.7  1.116149  0.18792  21.7111  1.2199  0.57861  678.85  254.36
# 88  46136.7  1.316575  0.16420  19.1252  1.0976  0.51439  483.28  225.07
# 89  48855.6  1.129016  0.20616  18.9052  1.0538  0.66461  500.31  226.26
#
#         BNT      BTS  ...    REP       SNT   THETA       TRX       VET  \
# ...

# %%
reward = today/sevenago-1
# reward.head(10)

# %%
reward["BBI"]= BBI
reward.head(10)
# Out:
#         BTC       ADA      ARDR      ATOM      ALGO       BAT       BCH  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6 -0.044232 -0.196055 -0.148779 -0.157773 -0.569105 -0.258614 -0.093354
# 7 -0.116797 -0.003790  0.111371 -0.082282 -0.610686  0.014895 -0.012653
# 8 -0.196671 -0.184248  0.016381 -0.239438 -0.702090 -0.070382 -0.259173
# 9 -0.197779 -0.208535 -0.113712  0.027306 -0.611553 -0.031164 -0.270784
#
#         BNB       BNT       BTS  ...       SNT     THETA       TRX       VET  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
reward = reward.dropna(axis=0,how='any')

# %%
reward
# Out:
#          BTC       ADA      ARDR      ATOM      ALGO       BAT       BCH  \
# 6  -0.044232 -0.196055 -0.148779 -0.157773 -0.569105 -0.258614 -0.093354
# 7  -0.116797 -0.003790  0.111371 -0.082282 -0.610686  0.014895 -0.012653
# 8  -0.196671 -0.184248  0.016381 -0.239438 -0.702090 -0.070382 -0.259173
# 9  -0.197779 -0.208535 -0.113712  0.027306 -0.611553 -0.031164 -0.270784
# 10 -0.134453 -0.097550  0.031628  0.402830 -0.369091  0.110684 -0.197207
# ..       ...       ...       ...       ...       ...       ...       ...
# 85  0.479838  0.893787  1.627291  0.731943  0.500557  2.067364  0.170611
# 86  0.184321  0.291542  1.298534 -0.075944 -0.301566  0.753039 -0.250853
# 87  0.020317  0.042251  0.865847 -0.077329  0.033527  0.927291 -0.218148
# 88  0.295030 -0.074927  2.961145  0.100009  0.264577  1.846576  0.391554
# 89  0.320401  0.352845  1.236079  0.276998  0.402258  1.279051  0.623993
#
#          BNB       BNT       BTS  ...       SNT     THETA       TRX       VET  \
# ...

# %%
reward.reset_index(drop=True, inplace=True)
reward
# Out:
#          BTC       ADA      ARDR      ATOM      ALGO       BAT       BCH  \
# 0  -0.044232 -0.196055 -0.148779 -0.157773 -0.569105 -0.258614 -0.093354
# 1  -0.116797 -0.003790  0.111371 -0.082282 -0.610686  0.014895 -0.012653
# 2  -0.196671 -0.184248  0.016381 -0.239438 -0.702090 -0.070382 -0.259173
# 3  -0.197779 -0.208535 -0.113712  0.027306 -0.611553 -0.031164 -0.270784
# 4  -0.134453 -0.097550  0.031628  0.402830 -0.369091  0.110684 -0.197207
# ..       ...       ...       ...       ...       ...       ...       ...
# 79  0.479838  0.893787  1.627291  0.731943  0.500557  2.067364  0.170611
# 80  0.184321  0.291542  1.298534 -0.075944 -0.301566  0.753039 -0.250853
# 81  0.020317  0.042251  0.865847 -0.077329  0.033527  0.927291 -0.218148
# 82  0.295030 -0.074927  2.961145  0.100009  0.264577  1.846576  0.391554
# 83  0.320401  0.352845  1.236079  0.276998  0.402258  1.279051  0.623993
#
#          BNB       BNT       BTS  ...       SNT     THETA       TRX       VET  \
# ...

# %%
reward.iloc[0,35]
# Out:
# 0

# %%
A = ['A','A']

# %%
# df = pd.DataFrame(columns=['lib', 'qty1', 'qty2', 'qty3','WWWW'])
df = pd.DataFrame

# %%
reward
# Out:
#          BTC       ADA      ARDR      ATOM      ALGO       BAT       BCH  \
# 0  -0.044232 -0.196055 -0.148779 -0.157773 -0.569105 -0.258614 -0.093354
# 1  -0.116797 -0.003790  0.111371 -0.082282 -0.610686  0.014895 -0.012653
# 2  -0.196671 -0.184248  0.016381 -0.239438 -0.702090 -0.070382 -0.259173
# 3  -0.197779 -0.208535 -0.113712  0.027306 -0.611553 -0.031164 -0.270784
# 4  -0.134453 -0.097550  0.031628  0.402830 -0.369091  0.110684 -0.197207
# ..       ...       ...       ...       ...       ...       ...       ...
# 79  0.479838  0.893787  1.627291  0.731943  0.500557  2.067364  0.170611
# 80  0.184321  0.291542  1.298534 -0.075944 -0.301566  0.753039 -0.250853
# 81  0.020317  0.042251  0.865847 -0.077329  0.033527  0.927291 -0.218148
# 82  0.295030 -0.074927  2.961145  0.100009  0.264577  1.846576  0.391554
# 83  0.320401  0.352845  1.236079  0.276998  0.402258  1.279051  0.623993
#
#          BNB       BNT       BTS  ...       SNT     THETA       TRX       VET  \
# ...

# %%
data
# Out:
#          Date      BTC       ADA     ARDR     ATOM    ALGO      BAT     BCH  \
# 0   28-Jul-19  10815.7  0.057739  0.06634   3.6882  0.7438  0.23479  335.39
# 1    4-Aug-19  11314.5  0.051980  0.05567   3.3458  0.8104  0.20275  316.13
# 2   11-Aug-19  10218.1  0.047360  0.05311   2.9089  0.6841  0.17675  306.59
# 3   18-Aug-19  10131.0  0.050097  0.06279   2.6917  0.5782  0.20312  305.52
# 4   25-Aug-19   9594.4  0.044777  0.05375   2.0140  0.4083  0.17708  279.25
# ..        ...      ...       ...      ...      ...     ...      ...     ...
# 85  14-Mar-21  58093.4  1.200409  0.28091  20.8997  1.2120  1.08189  536.21
# 86  21-Mar-21  55862.9  1.176785  0.28380  18.7088  1.1594  1.08166  500.34
# 87  28-Mar-21  57059.9  1.163307  0.35063  20.0322  1.2608  1.11515  530.76
# 88   4-Apr-21  59748.4  1.217928  0.65042  21.0379  1.3880  1.46425  672.51
# 89  11-Apr-21  64509.0  1.527384  0.46099  24.1419  1.4777  1.51468  812.50
#
# ...

# %%
for i in range(6,len(reward),1):
    rd = reward.iloc[i,35]
    if reward.iloc[i,35] == 0:
        print("熊式-----------------------------------")
        print("執行第",i) 
        q = reward.iloc[i:i+1,:35]
#         print(q)
        a = q.T
#         print(a)
#         print("執行第",i)    
        c = a.sort_values(by=[i])
#         print(c)
        d = c.T
#         print(d)
        e = d.iloc[:,0:5]
#         print(e)
        f= list(e.columns)
#         print(f)
        g = data.reindex(columns=f)
        h = g.shift(-7) / g.shift(-13) - 1 
        i = h.iloc[i-6,:]
        p = i.sum()
#         print(type(i))
#         print(i)

        result = pd.DataFrame(np.array([i]),
                   columns=f)
        print(type(i))
        print(result)
#         df.swapaxes("index", "columns") 
        result.to_csv('result.csv', mode='a', header=True)
#         j= i.sum()
        print(type(i))
        print(i)

#         print("報酬",j,"%")
        
    else :
        print("牛式===============================")
        print("執行第",i)     
        q = reward.iloc[i:i+1,:35] 
        a = q.T 
        c = a.sort_values(by=[i]) 
        d = c.T 
        e = d.iloc[:,30:36] 
        f= list(e.columns)
#         print(f)
        g = data.reindex(columns=f)
#         print(g)
        h = g.shift(-13)  / g.shift(-7) - 1 
#         print(h.head(25))
        i = h.iloc[i-6,:]
        result = pd.DataFrame(np.array([i]),
               columns=f)
        print(i)
        result.to_csv('result.csv', mode='a', header=True)
        j= i.sum()         
        print("報酬",j,"%")
# Out:
# 熊式-----------------------------------
# 執行第 6
# <class 'pandas.core.series.Series'>
#        ALGO       ETC       ICX       XMR      DASH
# 0  0.221448  0.249954  0.256804  0.168277  0.290864
# <class 'pandas.core.series.Series'>
# ALGO    0.221448
# ETC     0.249954
# ICX     0.256804
# XMR     0.168277
# DASH    0.290864
# Name: 0, dtype: float64
# 熊式-----------------------------------
# 執行第 7
# <class 'pandas.core.series.Series'>
#        DASH       BNT      ZEC       ICX      LTC
# 0 -0.004478  0.052682  0.09709  0.007994 -0.10684
# <class 'pandas.core.series.Series'>
# DASH   -0.004478
# BNT     0.052682
# ZEC     0.097090
# ICX     0.007994
# LTC    -0.106840
# Name: 1, dtype: float64
# 熊式-----------------------------------
# 執行第 8
# <class 'pandas.core.series.Series'>
#         ZEC       KNC       BNT      ARDR       BTS
# 0  0.028739  0.155429  0.090592  0.072461  0.087533
# <class 'pandas.core.series.Series'>
# ZEC     0.028739
# KNC     0.155429
# BNT     0.090592
# ...
