# %%
import pandas as pd
import numpy as np
from functools import partial, reduce

# %%
def date_manipulate(x):
    x = x.str.strip()
    x = x.str.replace(' ', '')
    x = x.str.replace('年', '-')
    x = x.str.replace('月', '-')
    x = x.str.replace('日', '')
    x = x.str.replace('号', '')
    x = x.str.replace('.', '-')
    x = x.str.replace('—', '-')
    x = pd.to_datetime(x, errors='coerce')
    return x

# %%
test = ['BTC','BTS','ADA']
data =['BTC','BTS','ADA']
for i in range(0,len(test)):
    data[i]= pd.read_csv(f'{test[i]}.csv',encoding="utf-8")
#     print(test[i])
    a = str(test[i])
#     print(a)
    data[i] = data[i].rename(columns={'收市': a,'日期':'Date'})
#     print("---------------------------------------------------------------")
#     print(test[i])
    print(data[i])
    data[i] = data[i].drop(['開市', '高', '低', '成交量','更改%'], axis=1)
#     print("=====================================================================")
#     print(data[i])
   

df_final = data[0]
for i in range(1,len(data)):
#     df = str(df)
#     print(data[i])
    df_final = df_final.merge(data[i], on=['Date'], how='outer')
#     print(data[0])
df_final
# print(df_final)
df_final['Date'] = date_manipulate(df_final['Date'])
df_final = df_final.sort_values(by=['Date'])
df_final = df_final.dropna(axis=0,how='any')
df_final
# Out:
#             Date       BTC        開市         高         低      成交量     更改%
# 0     2021年6月30日  35,026.9  35,832.6  36,089.5  34,126.6  107.07K  -2.25%
# 1     2021年6月29日  35,834.7  34,477.3  36,590.3  34,247.6   97.27K   3.94%
# 2     2021年6月28日  34,475.9  34,682.2  35,231.2  33,944.9  112.00K  -0.58%
# 3     2021年6月27日  34,678.5  32,247.1  34,685.5  32,041.7  148.80K   7.55%
# 4     2021年6月26日  32,243.4  31,592.1  32,643.0  30,206.9  156.67K   2.06%
# ...          ...       ...       ...       ...       ...      ...     ...
# 3996  2010年7月22日       0.1       0.1       0.1       0.1    2.16K   0.00%
# 3997  2010年7月21日       0.1       0.1       0.1       0.1    0.58K   0.00%
# 3998  2010年7月20日       0.1       0.1       0.1       0.1    0.26K   0.00%
# 3999  2010年7月19日       0.1       0.1       0.1       0.1    0.57K   0.00%
# 4000  2010年7月18日       0.1       0.0       0.1       0.1    0.08K   0.00%
#
# [4001 rows x 7 columns]
#             Date      BTS       開市        高        低      成交量      更改%
# 0      2021年7月3日  0.04431  0.04264  0.04511  0.04169   46.12M    3.91%
# 1      2021年7月2日  0.04264  0.04205  0.04277  0.04027   39.57M    1.17%
# 2      2021年7月1日  0.04215  0.04478  0.04483  0.04112   48.29M   -5.85%
